# %%
import pandas as pd

# %%
df = pd.read_csv("../data/item_properties_part2.csv")

# %%
df.head()
# Out:
#        timestamp  itemid property            value
# 0  1433041200000  183478      561           769062
# 1  1439694000000  132256      976  n26.400 1135780
# 2  1435460400000  420307      921  1149317 1257525
# 3  1431831600000  403324      917          1204143
# 4  1435460400000  230701      521           769062

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9275903 entries, 0 to 9275902
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  int64
#  1   itemid     int64
#  2   property   object
#  3   value      object
# dtypes: int64(2), object(2)
# memory usage: 283.1+ MB

# %%
df.shape
# Out:
# (9275903, 4)

# %%
# nulos
df.isnull().sum()
# Out:
# timestamp    0
# itemid       0
# property     0
# value        0
# dtype: int64

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms", utc=True)

# %%
print(df["timestamp"])
# Out:
# 0         2015-05-31 03:00:00+00:00
# 1         2015-08-16 03:00:00+00:00
# 2         2015-06-28 03:00:00+00:00
# 3         2015-05-17 03:00:00+00:00
# 4         2015-06-28 03:00:00+00:00
#                      ...
# 9275898   2015-06-07 03:00:00+00:00
# 9275899   2015-08-30 03:00:00+00:00
# 9275900   2015-08-16 03:00:00+00:00
# 9275901   2015-06-07 03:00:00+00:00
# 9275902   2015-09-13 03:00:00+00:00
# Name: timestamp, Length: 9275903, dtype: datetime64[ns, UTC]

# %%
# Mantém apenas as linhas cujas propriedades são 'categoryid' ou 'available', descartando as demais
mask = df["property"].isin(["categoryid", "available"])
df_props = df[mask]
