# %%
import pandas as pd

# %%
df = pd.read_csv("../data/events.csv")

# %%
df.head()
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN

# %%
df.shape
# Out:
# (2756101, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2756101 entries, 0 to 2756100
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   timestamp      int64
#  1   visitorid      int64
#  2   event          object
#  3   itemid         int64
#  4   transactionid  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 105.1+ MB

# %% [markdown]
# ### Qualidade dos dados

# %%
df.isnull().sum()
# Out:
# timestamp              0
# visitorid              0
# event                  0
# itemid                 0
# transactionid    2733644
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(460)

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms", utc=True)

# %%
print(df["timestamp"])
# Out:
# 0         2015-06-02 05:02:12.117000+00:00
# 1         2015-06-02 05:50:14.164000+00:00
# 2         2015-06-02 05:13:19.827000+00:00
# 3         2015-06-02 05:12:35.914000+00:00
# 4         2015-06-02 05:02:17.106000+00:00
#                         ...
# 2756096   2015-08-01 03:13:05.939000+00:00
# 2756097   2015-08-01 03:30:13.142000+00:00
# 2756098   2015-08-01 02:57:00.527000+00:00
# 2756099   2015-08-01 03:08:50.703000+00:00
# 2756100   2015-08-01 03:36:03.914000+00:00
# Name: timestamp, Length: 2756101, dtype: datetime64[ns, UTC]

# %%
# dropando as linhas duplicadas por serem poucas e não impactarem na análise
df = df.drop_duplicates()

# %%
df_events = df.drop(columns=["transactionid"], axis=1)

# %%
df_events.columns
# Out:
# Index(['visitorid', 'event', 'itemid'], dtype='object')
