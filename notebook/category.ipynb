# %%
import pandas as pd

# %% [markdown]
# ### Visão Geral dos Dados

# %%
df = pd.read_csv("../data/category_tree.csv")

# %%
df.head()
# Out:
#    categoryid  parentid
# 0        1016     213.0
# 1         809     169.0
# 2         570       9.0
# 3        1691     885.0
# 4         536    1691.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1669 entries, 0 to 1668
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   categoryid  1669 non-null   int64
#  1   parentid    1644 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 26.2 KB

# %% [markdown]
# ### Volume dos Dados

# %%
df.shape
# Out:
# (1669, 2)

# %% [markdown]
# ### Qualidade dos Dados

# %%
#nulos
df.isnull().sum()
# Out:
# categoryid     0
# parentid      25
# dtype: int64

# %%
#duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Drop dos valores duplicados

# %%
df["parentid"] = df["parentid"].fillna(-1).astype(int)  # -1 = raiz
