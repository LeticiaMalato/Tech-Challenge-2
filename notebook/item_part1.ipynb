# %%
import pandas as pd

# %% [markdown]
# ### Visão Geral

# %%
df = pd.read_csv("../data/item_properties_part1.csv")

# %%
df.head()
# Out:
#        timestamp  itemid    property                            value
# 0  1435460400000  460429  categoryid                             1338
# 1  1441508400000  206783         888          1116713 960601 n277.200
# 2  1439089200000  395014         400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481         790                       n15360.000
# 4  1431831600000  156781         917                           828513

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999999 entries, 0 to 10999998
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   timestamp  int64
#  1   itemid     int64
#  2   property   object
#  3   value      object
# dtypes: int64(2), object(2)
# memory usage: 335.7+ MB

# %% [markdown]
# ### Volume de Dados

# %%
df.shape
# Out:
# (10999999, 4)

# %% [markdown]
# ### Qualidade dos Dados

# %%
#nulos 
df.isnull().sum()
# Out:
# timestamp    0
# itemid       0
# property     0
# value        0
# dtype: int64

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms", utc=True)

# %%
print(df["timestamp"])
# Out:
# 0          2015-06-28 03:00:00+00:00
# 1          2015-09-06 03:00:00+00:00
# 2          2015-08-09 03:00:00+00:00
# 3          2015-05-10 03:00:00+00:00
# 4          2015-05-17 03:00:00+00:00
#                       ...
# 10999994   2015-08-16 03:00:00+00:00
# 10999995   2015-06-28 03:00:00+00:00
# 10999996   2015-08-23 03:00:00+00:00
# 10999997   2015-07-26 03:00:00+00:00
# 10999998   2015-07-05 03:00:00+00:00
# Name: timestamp, Length: 10999999, dtype: datetime64[ns, UTC]

# %%
# Mantém apenas as linhas cujas propriedades são 'categoryid' ou 'available', descartando as demais
mask = df["property"].isin(["categoryid", "available"])
df_props = df[mask]
